# %%
pip install sec-api

# %%
from sec_api import ExtractorApi, XbrlApi

xbrlApi = XbrlApi("cd7563c802fbe2454e9c32683971b83203f25c8e944159e2822bd3b7d31e5a8f")
extractorApi = ExtractorApi(api_key="cd7563c802fbe2454e9c32683971b83203f25c8e944159e2822bd3b7d31e5a8f")

# %%
filing_urls =["https://www.sec.gov/Archives/edgar/data/0000320193/000119312509214859/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312510238044/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312511282113/d220209d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312512444068/d411355d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312513416534/d590790d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312514383437/d783162d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312515356351/d17062d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000162828016020309/a201610-k9242016.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019317000070/a10-k20179302017.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019318000145/a10-k20189292018.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019319000119/a10-k20199282019.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019320000096/aapl-20200926.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019321000105/aapl-20210925.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019322000108/aapl-20220924.htm"]

for i, filing_url in enumerate(filing_urls, 1):
    section_text = extractorApi.get_section(filing_url, "7", "text")
    try:
        xbrl_json = xbrlApi.xbrl_to_json(htm_url=filing_url)
        result = [f"{key}: {value}\n" for key, value in xbrl_json["CoverPage"].items()]
        filename = f'apple_7section/AAPL_filings_{i}.txt'
        with open(filename, 'w') as f:
            for item in result:
                f.write(item)
            f.write(section_text)
    except Exception as e:
        if "The filer did not attach XBRL data to the filing" in str(e):
            print(f"Skipping {filing_url} - No XBRL data found.")
        else:
            print(f"Error processing {filing_url}: {e}")
            raise

# %%
filing_urls =["https://www.sec.gov/Archives/edgar/data/0000320193/000119312509214859/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312510238044/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312511282113/d220209d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312512444068/d411355d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312513416534/d590790d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312514383437/d783162d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312515356351/d17062d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000162828016020309/a201610-k9242016.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019317000070/a10-k20179302017.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019318000145/a10-k20189292018.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019319000119/a10-k20199282019.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019320000096/aapl-20200926.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019321000105/aapl-20210925.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019322000108/aapl-20220924.htm"]

for i, filing_url in enumerate(filing_urls, 1):
    section_text = extractorApi.get_section(filing_url, "1", "text")
    try:
        xbrl_json = xbrlApi.xbrl_to_json(htm_url=filing_url)
        result = [f"{key}: {value}\n" for key, value in xbrl_json["CoverPage"].items()]
        filename = f'apple_1section/AAPL_filings_{i}.txt'
        with open(filename, 'w') as f:
            for item in result:
                f.write(item)
            f.write(section_text)
    except Exception as e:
        if "The filer did not attach XBRL data to the filing" in str(e):
            print(f"Skipping {filing_url} - No XBRL data found.")
        else:
            print(f"Error processing {filing_url}: {e}")
            raise

# %%
xbrlApi = XbrlApi("4c3d1ff61176058c9d88d10728dbb7fa99bc195d7b4437c543d73197d675deb7")
extractorApi = ExtractorApi(api_key="4c3d1ff61176058c9d88d10728dbb7fa99bc195d7b4437c543d73197d675deb7")


filing_urls =["https://www.sec.gov/Archives/edgar/data/0000320193/000119312509214859/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312510238044/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312511282113/d220209d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312512444068/d411355d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312513416534/d590790d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312514383437/d783162d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312515356351/d17062d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000162828016020309/a201610-k9242016.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019317000070/a10-k20179302017.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019318000145/a10-k20189292018.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019319000119/a10-k20199282019.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019320000096/aapl-20200926.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019321000105/aapl-20210925.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019322000108/aapl-20220924.htm"]

for i, filing_url in enumerate(filing_urls, 1):
    section_text = extractorApi.get_section(filing_url, "1A", "text")
    try:
        xbrl_json = xbrlApi.xbrl_to_json(htm_url=filing_url)
        result = [f"{key}: {value}\n" for key, value in xbrl_json["CoverPage"].items()]
        filename = f'apple_1asection/AAPL_filings_{i}.txt'
        with open(filename, 'w') as f:
            for item in result:
                f.write(item)
            f.write(section_text)
    except Exception as e:
        if "The filer did not attach XBRL data to the filing" in str(e):
            print(f"Skipping {filing_url} - No XBRL data found.")
        else:
            print(f"Error processing {filing_url}: {e}")
            raise

# %%
filing_urls =["https://www.sec.gov/Archives/edgar/data/0000320193/000119312509214859/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312510238044/d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312511282113/d220209d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312512444068/d411355d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312513416534/d590790d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312514383437/d783162d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000119312515356351/d17062d10k.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000162828016020309/a201610-k9242016.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019317000070/a10-k20179302017.htm","https://www.sec.gov/Archives/edgar/data/0000320193/000032019318000145/a10-k20189292018.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019319000119/a10-k20199282019.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019320000096/aapl-20200926.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019321000105/aapl-20210925.htm","https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000032019322000108/aapl-20220924.htm"]

for i, filing_url in enumerate(filing_urls, 1):
    section_text = extractorApi.get_section(filing_url, "8", "text")
    try:
        xbrl_json = xbrlApi.xbrl_to_json(htm_url=filing_url)
        result = [f"{key}: {value}\n" for key, value in xbrl_json["CoverPage"].items()]
        filename = f'apple_8section/AAPL_filings_{i}.txt'
        with open(filename, 'w') as f:
            for item in result:
                f.write(item)
            f.write(section_text)
    except Exception as e:
        if "The filer did not attach XBRL data to the filing" in str(e):
            print(f"Skipping {filing_url} - No XBRL data found.")
        else:
            print(f"Error processing {filing_url}: {e}")
            raise

# %%
import cohere
from dotenv import load_dotenv
import os

# Load your Cohere API key from an environment variable
# load_dotenv()
# api_key = os.getenv("N7qG6ka2MQ3Tt7PcIheilFVKlWtRONo7UY7qX70n")

# Initialize the Cohere client
co = cohere.Client("N7qG6ka2MQ3Tt7PcIheilFVKlWtRONo7UY7qX70n")

# # Read the contents of your 10-K filings
# with open(r"C:\Users\srima\Fintech\amazon_10k_fillings\sec-edgar-filings\AMZN\10-K\0000891020-00-000622\full-submission.txt", "r", encoding="utf-8") as f:
#     text = f.read()


filings_dir = r"C:\Users\srima\Fintech\apple_7section"
restart_sequence = "\n\n###\n\n"
# Initialize an empty string to store the concatenated text
combined_text = []

# Loop through all files in the directory
for filename in os.listdir(filings_dir):
    file_path = os.path.join(filings_dir, filename)
    
    # Check if the file is a text file
        # Check if the file is a text file
    # Check if the file is a text file
    if file_path.endswith(".txt"):
        with open(file_path, "r", encoding="utf-8") as f:
            try:
                text = f.read()
            except UnicodeDecodeError:
            # Handle the error, e.g., try a different encoding or ignore/replace invalid bytes
                with open(file_path, "rb") as f:
                    text = f.read().decode('utf-8', errors='replace')
            combined_text.append(text)  # Separate files with newlines

# %%
prompt = f"Based on the following past 10-K filings given, provide a detailed analysis and insights considering the its progression over time such that I have to make a visualization from the insighs, so give proper insights which I can make a visualization from them(that is give code to plot with extracting values and everything) :\n\n{combined_text[0]}\n\nAnalysis and Insights:"

prompt = restart_sequence + prompt
# Use the Cohere API's generate function to generate the analysis and insights
response = co.generate(
    model='command-r-plus',
    prompt=prompt,
    max_tokens=5000,
    temperature=0.7,
    k=0,
    p=1,
    frequency_penalty=0,
    presence_penalty=0,
    stop_sequences=["--"],
    return_likelihoods='NONE'
   )

# Print the generated analysis and insights
output=[]
output.append(response.generations[0].text)
print(response.generations[0].text)

for i in range(1,len(combined_text)) :
   prompt = f"Based on the following past 10-K filings given, provide a detailed analysis and insights considering the its progression over time such that I have to make a visualization from the insighs, so give proper insights which I can make a visualization from them(that is give code to plot with extracting values and everything) :\n\n{combined_text[i]}\n\nAnalysis and Insights:"
   prompt = f"{response.generations[0].text}{restart_sequence}{prompt}"
   response = co.generate(
    model='command-r-plus',
    prompt=prompt,
    max_tokens=5000,
    temperature=0.7,
    k=0,
    p=1,
    frequency_penalty=0,
    presence_penalty=0,
    stop_sequences=["--"],
    return_likelihoods='NONE'
    )
   output.append(response.generations[0].text)

prompt = f"Based on the following past 14 years 10-K filings given, provide a final detailed analysis and insights considering the its progression over time such that I have to make a visualization from the insighs, so give proper insights which I can make a visualization from them(that is give code to plot with extracting values and everything) :\n\n\n\nAnalysis and Insights:"
prompt = f"{response.generations[0].text}{restart_sequence}{prompt}"
response = co.generate(
        model='command-r-plus',
        prompt=prompt,
        max_tokens=5000,
        temperature=0.7,
        k=0,
        p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop_sequences=["--"],
        return_likelihoods='NONE'
        )
output.append(response.generations[0].text)
print(response.generations[0].text)
# Out:
# Here is a detailed analysis and insights into the provided 10-K filings:
#
# - **Executive Overview**: Apple Inc., as per the filings, designs, manufactures, and markets a range of products, including personal computers, mobile communication devices, digital music and video players, and related software, services, peripherals, and networking solutions. The company's primary products include iPhones, iPads, Macs, Apple Watches, AirPods, Apple TVs, HomePods, and a range of accessories, software, and services.
# - **Financial Performance**: Apple's net sales increased from $32.48 billion in 2008 to $36.54 billion in 2009, a rise of 12%. This growth was driven by increased iPhone revenue, higher sales of third-party digital content, and strong demand for Mac portable systems. Net sales further increased to $39.33 billion in 2010 and $108.25 billion in 2011, indicating a consistent upward trend.
# ...
